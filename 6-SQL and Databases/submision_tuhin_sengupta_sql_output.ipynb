# %%
import pandas as pd

result1 = pd.read_csv('submission_myname-output-1.csv')
result2 = pd.read_csv('submission_myname-output-2.csv')
result3 = pd.read_csv('submission_myname-output-3.csv')
result4 = pd.read_csv('submission_myname-output-4.csv')
result5 = pd.read_csv('submission_myname-output-5.csv')
result6 = pd.read_csv('submission_myname-output-6.csv')
result7 = pd.read_csv('submission_myname-output-7.csv')
result8 = pd.read_csv('submission_myname-output-8.csv')
result9 = pd.read_csv('submission_myname-output-9.csv')
result10 = pd.read_csv('submission_myname-output-10.csv')

# %% [markdown]
# [Q1] What is the distribution of customers across states?

# %%
result1.head(result1.shape[0])
# Out:
#                    state  customer_count
# 0             California              97
# 1                  Texas              97
# 2                Florida              86
# 3               New York              69
# 4   District of Columbia              35
# 5               Colorado              33
# 6                   Ohio              33
# 7                Alabama              29
# 8             Washington              28
# 9                Arizona              26
# 10              Illinois              25
# 11          Pennsylvania              25
# 12              Virginia              24
# 13             Tennessee              23
# 14              Missouri              23
# 15           Connecticut              22
# 16               Indiana              21
# 17             Louisiana              20
# 18        North Carolina              20
# 19               Georgia              18
# 20             Minnesota              17
# 21                Nevada              17
# ...

# %% [markdown]
# [Q2] What is the average rating in each quarter?

# %%
result2.head(result3.shape[0])
# Out:
#    quarter_number  average_rating
# 0               1          3.6663
# 1               2          3.4840
# 2               3          3.0807
# 3               4          2.5131

# %% [markdown]
# [Q3] Are customers getting more dissatisfied over time?

# %%
result3.head(result3.shape[0])
# Out:
#     quarter_number customer_feedback  feedback_count  total_count  \
# 0                1               Bad              35          310
# 1                1              Good              89          310
# 2                1              Okay              59          310
# 3                1          Very Bad              34          310
# 4                1         Very Good              93          310
# 5                2               Bad              37          262
# 6                2              Good              58          262
# 7                2              Okay              53          262
# 8                2          Very Bad              39          262
# 9                2         Very Good              75          262
# 10               3               Bad              52          229
# 11               3              Good              48          229
# 12               3              Okay              50          229
# ...

# %% [markdown]
# [Q4] Which are the top 5 vehicle makers preferred by the customer?

# %%
result4.head(result4.shape[0])
# Out:
#   vehicle_maker  customer_count
# 0     Chevrolet              83
# 1          Ford              63
# 2        Toyota              52
# 3         Dodge              50
# 4       Pontiac              50

# %% [markdown]
# [Q5] What is the most preferred vehicle make in each state?

# %%
pd.set_option('display.max_rows', result5.shape[0]) 
result5.head(result5.shape[0])
# Out:
#                     state  vehicle_maker
# 0                 Alabama          Dodge
# 1                  Alaska      Chevrolet
# 2                 Arizona       Cadillac
# 3                 Arizona        Pontiac
# 4                Arkansas      Chevrolet
# 5                Arkansas            GMC
# 6                Arkansas     Mitsubishi
# 7                Arkansas        Pontiac
# 8                Arkansas         Suzuki
# 9                Arkansas     Volkswagen
# 10             California           Audi
# 11             California      Chevrolet
# 12             California          Dodge
# 13             California           Ford
# 14             California         Nissan
# 15               Colorado      Chevrolet
# 16            Connecticut      Chevrolet
# 17            Connecticut       Maserati
# 18            Connecticut        Mercury
# 19            Connecticut          Volvo
# 20               Delaware     Mitsubishi
# 21   District of Columbia      Chevrolet
# ...

# %% [markdown]
# [Q6] What is the trend of number of orders by quarters?

# %%
result6.head(result6.shape[0])
# Out:
#    quarter_number  order_count
# 0               1          310
# 1               2          262
# 2               3          229
# 3               4          199

# %% [markdown]
# [Q7] What is the quarter over quarter % change in revenue?

# %%
result7.head(result7.shape[0])
# Out:
#    quarter_number  current_quarter_revenue  previous_quarter_revenue  \
# 0               1              26519199.19                       NaN
# 1               2              21595874.35               26519199.19
# 2               3              19719917.59               21595874.35
# 3               4              15280009.98               19719917.59
#
#    qoq_percentage_change
# 0                    NaN
# 1             -18.565134
# 2              -8.686644
# 3             -22.514839

# %% [markdown]
# [Q8] What is the trend of revenue and orders by quarters?

# %%
result8.head(result8.shape[0])
# Out:
#    quarter_number  total_revenue  total_orders
# 0               1    26519199.19           310
# 1               2    21595874.35           262
# 2               3    19719917.59           229
# 3               4    15280009.98           199

# %% [markdown]
# [Q9] What is the average discount offered for different types of credit cards?

# %%
result9.head(result9.shape[0])
# Out:
#              credit_card_type  average_discount
# 0                         jcb          0.607382
# 1               visa-electron          0.623469
# 2                      switch          0.610233
# 3   diners-club-carte-blanche          0.614490
# 4                       laser          0.643846
# 5              china-unionpay          0.622174
# 6         diners-club-enroute          0.599792
# 7             americanexpress          0.616327
# 8                  mastercard          0.629500
# 9                        visa          0.600833
# 10                   bankcard          0.609545
# 11                       solo          0.585000
# 12                    maestro          0.624219
# 13          diners-club-us-ca          0.614615
# 14               instapayment          0.620625
# 15  diners-club-international          0.584000

# %% [markdown]
# [Q10] What is the average time taken to ship the placed orders for each quarters?

# %%
result10.head(result10.shape[0])
# Out:
#    quarter_number  average_shipping_time
# 0               1                57.1677
# 1               2                71.1107
# 2               3               117.7555
# 3               4               174.0955
