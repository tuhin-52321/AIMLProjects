# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Q1.a

# %%
df1 = pd.read_csv('Car name.csv')

# %% [markdown]
# ### Q1.b

# %%
df2 = pd.read_json('Car-Attributes.json')

# %%
df1.head()
# Out:
#                     car_name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
df1.shape
# Out:
# (398, 1)

# %%
lst=df1.car_name.unique()
names=lst.tolist()

# %%
len(names)
# Out:
# 305

# %%
df1[df1.duplicated(keep=False)]['car_name'].unique()
# Out:
# array(['chevrolet chevelle malibu', 'ford galaxie 500',
#        'chevrolet impala', 'plymouth fury iii', 'pontiac catalina',
#        'buick estate wagon (sw)', 'plymouth duster', 'amc hornet',
#        'ford maverick', 'datsun pl510', 'peugeot 504', 'amc gremlin',
#        'toyota corona', 'ford pinto', 'amc matador',
#        'ford country squire (sw)', 'opel 1900', 'toyota corolla 1200',
#        'chevrolet vega', 'amc matador (sw)', 'ford gran torino (sw)',
#        'chevrolet malibu', 'ford gran torino',
#        'chevrolet caprice classic', 'ford ltd', 'plymouth valiant',
#        'fiat 128', 'opel manta', 'audi 100ls', 'saab 99le',
#        'toyota mark ii', 'chevrolet nova',
#        'chevrolet chevelle malibu classic', 'volkswagen dasher',
#        'datsun 710', 'dodge colt', 'honda civic', 'subaru',
#        'buick century', 'toyota corolla', 'volkswagen rabbit',
#        'honda civic cvcc', 'chevrolet chevette', 'vw rabbit',
# ...

# %%
df2.head()
# Out:
#     mpg  cyl   disp   hp    wt   acc  yr  origin
# 0  18.0    8  307.0  130  3504  12.0  70       1
# 1  15.0    8  350.0  165  3693  11.5  70       1
# 2  18.0    8  318.0  150  3436  11.0  70       1
# 3  16.0    8  304.0  150  3433  12.0  70       1
# 4  17.0    8  302.0  140  3449  10.5  70       1

# %%
df2.shape
# Out:
# (398, 8)

# %% [markdown]
# ### Q1.c

# %%
df = [df1,df2]

# %%
df
# Out:
# [                      car_name
#  0    chevrolet chevelle malibu
#  1            buick skylark 320
#  2           plymouth satellite
#  3                amc rebel sst
#  4                  ford torino
#  ..                         ...
#  393            ford mustang gl
#  394                  vw pickup
#  395              dodge rampage
#  396                ford ranger
#  397                 chevy s-10
#
#  [398 rows x 1 columns],       mpg  cyl   disp   hp    wt   acc  yr  origin
#  0    18.0    8  307.0  130  3504  12.0  70       1
#  1    15.0    8  350.0  165  3693  11.5  70       1
#  2    18.0    8  318.0  150  3436  11.0  70       1
#  3    16.0    8  304.0  150  3433  12.0  70       1
#  4    17.0    8  302.0  140  3449  10.5  70       1
#  ..    ...  ...    ...  ...   ...   ...  ..     ...
#  393  27.0    4  140.0   86  2790  15.6  82       1
#  394  44.0    4   97.0   52  2130  24.6  82       2
#  395  32.0    4  135.0   84  2295  11.6  82       1
# ...

# %%
df = pd.concat(df,axis=1)

# %%
df.head()
# Out:
#                     car_name   mpg  cyl   disp   hp    wt   acc  yr  origin
# 0  chevrolet chevelle malibu  18.0    8  307.0  130  3504  12.0  70       1
# 1          buick skylark 320  15.0    8  350.0  165  3693  11.5  70       1
# 2         plymouth satellite  18.0    8  318.0  150  3436  11.0  70       1
# 3              amc rebel sst  16.0    8  304.0  150  3433  12.0  70       1
# 4                ford torino  17.0    8  302.0  140  3449  10.5  70       1

# %%
df.shape
# Out:
# (398, 9)

# %%
df[df['car_name']=='datsun 710']
# Out:
#        car_name   mpg  cyl   disp  hp    wt   acc  yr  origin
# 145  datsun 710  32.0    4   83.0  61  2003  19.0  74       3
# 173  datsun 710  24.0    4  119.0  97  2545  17.0  75       3

# %% [markdown]
# ### Q1.d

# %%
df.describe()
# Out:
#               mpg         cyl        disp           wt         acc  \
# count  398.000000  398.000000  398.000000   398.000000  398.000000
# mean    23.514573    5.454774  193.425879  2970.424623   15.568090
# std      7.815984    1.701004  104.269838   846.841774    2.757689
# min      9.000000    3.000000   68.000000  1613.000000    8.000000
# 25%     17.500000    4.000000  104.250000  2223.750000   13.825000
# 50%     23.000000    4.000000  148.500000  2803.500000   15.500000
# 75%     29.000000    8.000000  262.000000  3608.000000   17.175000
# max     46.600000    8.000000  455.000000  5140.000000   24.800000
#
#                yr      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ### Q2.a

# %%
df.isna().sum()/len(df)*100
# Out:
# car_name    0.0
# mpg         0.0
# cyl         0.0
# disp        0.0
# hp          0.0
# wt          0.0
# acc         0.0
# yr          0.0
# origin      0.0
# dtype: float64

# %% [markdown]
# ### Q2.b

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_name, mpg, cyl, disp, hp, wt, acc, yr, origin]
# Index: []

# %%
df.origin.value_counts()
# Out:
# origin
# 1    249
# 3     79
# 2     70
# Name: count, dtype: int64

# %% [markdown]
# ### Q2.c

# %%
sns.pairplot(df,hue='cyl',palette='tab10')
# Out:
# C:\Users\tuhin.sengupta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Q2.d

# %%
#Create a scatterplot of DF for attributes 'wt' and 'disp' with hue as 'cyl'
sns.scatterplot(x=df['wt'], y=df['disp'],hue=df['cyl'],palette='tab10')
# Out:
# <Axes: xlabel='wt', ylabel='disp'>

# %% [markdown]
# ### Q2.e

# %% [markdown]
# 1. 'wt' is having positive linear relationship with cylinder displacement.
# 2. 'wt' and cylinder displacement is increasing along with increase in Number of Cylinders.
# 3. There are more vehicles with 4 cylinders and 8 cylinders than 3,5 & 6

# %% [markdown]
# ### Q2.f

# %%
sns.scatterplot(x=df['wt'],y=df['mpg'],hue=df['cyl'],palette='tab10')
# Out:
# <Axes: xlabel='wt', ylabel='mpg'>

# %% [markdown]
# ### Q2.g

# %% [markdown]
# 1. Mileage decreases with increase in wt.
# 2. Mileage reduces with increased number of cylinders.

# %%
df.head()
# Out:
#                     car_name   mpg  cyl   disp   hp    wt   acc  yr  origin
# 0  chevrolet chevelle malibu  18.0    8  307.0  130  3504  12.0  70       1
# 1          buick skylark 320  15.0    8  350.0  165  3693  11.5  70       1
# 2         plymouth satellite  18.0    8  318.0  150  3436  11.0  70       1
# 3              amc rebel sst  16.0    8  304.0  150  3433  12.0  70       1
# 4                ford torino  17.0    8  302.0  140  3449  10.5  70       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   car_name  398 non-null    object
#  1   mpg       398 non-null    float64
#  2   cyl       398 non-null    int64
#  3   disp      398 non-null    float64
#  4   hp        398 non-null    object
#  5   wt        398 non-null    int64
#  6   acc       398 non-null    float64
#  7   yr        398 non-null    int64
#  8   origin    398 non-null    int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# ### Q2.h

# %%
for i in df['hp']:
    if not str(i).isdigit():
        print(i)
#     print(i)
# Out:
# ?
# ?
# ?
# ?
# ?
# ?

# %%
df['hp'] = np.where(df['hp']=='?',np.nan,df['hp'])

# %%
df.isna().sum()
# Out:
# car_name    0
# mpg         0
# cyl         0
# disp        0
# hp          6
# wt          0
# acc         0
# yr          0
# origin      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
# df.drop('car_name',axis=1,inplace=True)
X = df.drop('car_name',axis=1)

# %%
df.hp.value_counts()
# Out:
# hp
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
#        ..
# 61      1
# 93      1
# 148     1
# 152     1
# 82      1
# Name: count, Length: 93, dtype: int64

# %% [markdown]
# ### Q3.a, Q3.b, Q3.c

# %%
from sklearn.cluster import KMeans

clusters = []

for i in range(1, 11):
    km = KMeans(n_clusters=i).fit(X)
    clusters.append(km.inertia_)
    print(km.inertia_)
    
fig, ax = plt.subplots(figsize=(12, 8))
sns.lineplot(x=list(range(1, 11)), y=clusters, ax=ax,marker='o')
ax.set_title('Searching for Elbow')
ax.set_xlabel('Clusters')
ax.set_ylabel('Inertia')

# Annotate arrow
ax.annotate('Possible Elbow Points', xy=(2,72921239.89189374), xytext=(4, 100000000), xycoords='data',          
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='orange', lw=2))

ax.annotate('Possible Elbow Points', xy=(5, 18811096.49806816), xytext=(4, 100000000), xycoords='data',          
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='orange', lw=2))

ax.annotate('Possible Elbow Points', xy=(3,33849580.50405829), xytext=(4, 100000000), xycoords='data',          
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='orange', lw=2))


plt.show()
# Out:
# C:\Users\tuhin.sengupta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 286994900.8243622
# 72921239.89189374
# 33849200.977828786
# 18811096.49806818
# 13496976.592313793
# 10197039.94023752
# 7586787.11419084
# C:\Users\tuhin.sengupta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# ### Q3.d, Q3.e, Q3.f

# %%
# 3 cluster
km3 = KMeans(n_clusters=3).fit(X)

df['Labels_3'] = km3.labels_
plt.figure(figsize=(12, 8))
sns.scatterplot(x=df['wt'], y=df['mpg'], hue=df['Labels_3'], 
                palette=sns.color_palette('hls', 3))
plt.title('KMeans with 3 Clusters')
plt.show()
# Out:
# C:\Users\tuhin.sengupta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# g = sns.PairGrid(df, vars=["wt", "mpg"], hue="Labels",palette='tab10',)
# g.map(sns.scatterplot)

# %%
df.head()
# Out:
#                     car_name   mpg  cyl   disp   hp    wt   acc  yr  origin  \
# 0  chevrolet chevelle malibu  18.0    8  307.0  130  3504  12.0  70       1
# 1          buick skylark 320  15.0    8  350.0  165  3693  11.5  70       1
# 2         plymouth satellite  18.0    8  318.0  150  3436  11.0  70       1
# 3              amc rebel sst  16.0    8  304.0  150  3433  12.0  70       1
# 4                ford torino  17.0    8  302.0  140  3449  10.5  70       1
#
#    Labels_3
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0

# %%
sns.scatterplot(data=df,x='wt',y='mpg',hue='Labels_3',palette='tab10')
# Out:
# <Axes: xlabel='wt', ylabel='mpg'>

# %%
sns.scatterplot(data=df,y='hp',x='wt',hue='Labels_3',palette='tab10')
# Out:
# <Axes: xlabel='wt', ylabel='hp'>

# %%
# 5 cluster
km5 = KMeans(n_clusters=5).fit(X)

df['Labels_5'] = km5.labels_
plt.figure(figsize=(12, 8))
sns.scatterplot(x=df['wt'], y=df['mpg'], hue=df['Labels_5'], 
                palette=sns.color_palette('hls', 5))
plt.title('KMeans with 5 Clusters')
plt.show()
# Out:
# C:\Users\tuhin.sengupta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
g = sns.PairGrid(df, vars=["wt", "mpg"], hue="Labels_5",palette='tab10',)
g.map(sns.scatterplot)

# %%
sns.scatterplot(data=df,x='wt',y='mpg',hue='Labels_5',palette='tab10')
# Out:
# <Axes: xlabel='wt', ylabel='mpg'>

# %%
sns.scatterplot(data=df,y='hp',x='wt',hue='Labels_5',palette='tab10',)
# Out:
# <Axes: xlabel='wt', ylabel='hp'>

# %%
df.head()
# Out:
#                     car_name   mpg  cyl   disp   hp    wt   acc  yr  origin  \
# 0  chevrolet chevelle malibu  18.0    8  307.0  130  3504  12.0  70       1
# 1          buick skylark 320  15.0    8  350.0  165  3693  11.5  70       1
# 2         plymouth satellite  18.0    8  318.0  150  3436  11.0  70       1
# 3              amc rebel sst  16.0    8  304.0  150  3433  12.0  70       1
# 4                ford torino  17.0    8  302.0  140  3449  10.5  70       1
#
#    Labels_3  Labels_5
# 0         0         2
# 1         1         0
# 2         0         2
# 3         0         2
# 4         0         2

# %% [markdown]
# ### Q3.g

# %%
km3.predict([[18,8,350,130,3504,12,70,1]])[0]
# Out:
# C:\Users\tuhin.sengupta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# 0

# %% [markdown]
# # Part 2

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV, KFold

# %% [markdown]
# ### Q1.a

# %%
cars = pd.read_csv('vehicle.csv')

# %%
cars.head()
# Out:
#    compactness  circularity  distance_circularity  radius_ratio  \
# 0           95         48.0                  83.0         178.0
# 1           91         41.0                  84.0         141.0
# 2          104         50.0                 106.0         209.0
# 3           93         41.0                  82.0         159.0
# 4           85         44.0                  70.0         205.0
#
#    pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0                  72.0                       10          162.0
# 1                  57.0                        9          149.0
# 2                  66.0                       10          207.0
# 3                  63.0                        9          144.0
# 4                 103.0                       52          149.0
#
#    elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 0           42.0                    20.0                        159
# ...

# %% [markdown]
# ### Q1.b

# %%
cars.isna().sum()/len(df)*100
# Out:
# compactness                    0.000000
# circularity                    1.275510
# distance_circularity           1.020408
# radius_ratio                   1.530612
# pr.axis_aspect_ratio           0.510204
# max.length_aspect_ratio        0.000000
# scatter_ratio                  0.255102
# elongatedness                  0.255102
# pr.axis_rectangularity         0.765306
# max.length_rectangularity      0.000000
# scaled_variance                0.765306
# scaled_variance.1              0.510204
# scaled_radius_of_gyration      0.510204
# scaled_radius_of_gyration.1    1.020408
# skewness_about                 1.530612
# skewness_about.1               0.255102
# skewness_about.2               0.255102
# hollows_ratio                  0.000000
# class                          0.000000
# dtype: float64

# %%
cars.dropna(inplace=True)

# %%
cars.isna().sum()/len(df)*100
# Out:
# compactness                    0.0
# circularity                    0.0
# distance_circularity           0.0
# radius_ratio                   0.0
# pr.axis_aspect_ratio           0.0
# max.length_aspect_ratio        0.0
# scatter_ratio                  0.0
# elongatedness                  0.0
# pr.axis_rectangularity         0.0
# max.length_rectangularity      0.0
# scaled_variance                0.0
# scaled_variance.1              0.0
# scaled_radius_of_gyration      0.0
# scaled_radius_of_gyration.1    0.0
# skewness_about                 0.0
# skewness_about.1               0.0
# skewness_about.2               0.0
# hollows_ratio                  0.0
# class                          0.0
# dtype: float64

# %% [markdown]
# ### Q1.c

# %%
cars['class'].value_counts().plot(kind='pie',figsize=(11, 6),autopct='%1.2f%%',)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Q1.d

# %%
cars.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Q2.a

# %%
X = cars.drop('class',axis=1)

# %%
sc = StandardScaler()

# %% [markdown]
# ### Q2.b

# %%
X = sc.fit_transform(X)

# %%
y = cars['class']

# %% [markdown]
# ### Q3.a

# %%
svm = SVC()

# %%
svm.fit(X,y)
# Out:
# SVC()

# %%
pred = svm.predict(X)

# %% [markdown]
# ### Q3.b

# %%
print(classification_report(y,pred))
# Out:
#               precision    recall  f1-score   support
#
#          bus       0.99      0.99      0.99       205
#          car       0.99      0.98      0.99       413
#          van       0.95      0.97      0.96       195
#
#     accuracy                           0.98       813
#    macro avg       0.98      0.98      0.98       813
# weighted avg       0.98      0.98      0.98       813

# %% [markdown]
# ### Q3.c, Q3.d, Q3.e

# %%
pca=PCA(n_components=10)
pca_data=pca.fit_transform(X)
percentage_var_explained=pca.explained_variance_/np.sum(pca.explained_variance_)

cum_var_explained=np.cumsum(percentage_var_explained)

plt.figure(1,figsize=(12,8))
plt.clf()
plt.plot(cum_var_explained,linewidth=2,marker='o')
plt.plot((0,9),(0.9,0.9),'--',marker='o')
plt.grid()
plt.xlabel('n_components')
plt.ylabel('Cumulative_explained_Variance')
plt.show()

# %% [markdown]
# ### Q3.f

# %%
pca=PCA(n_components=4)
pca_data_1=pca.fit_transform(X)

# %% [markdown]
# ### Q3.g

# %%
svm.fit(pca_data_1,y)
# Out:
# SVC()

# %%
pred_svm = svm.predict(pca_data_1)

# %% [markdown]
# ### Q3.h

# %%
print(classification_report(y,pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#          bus       0.85      0.66      0.75       205
#          car       0.85      0.88      0.86       413
#          van       0.66      0.76      0.71       195
#
#     accuracy                           0.80       813
#    macro avg       0.79      0.77      0.77       813
# weighted avg       0.80      0.80      0.80       813

# %% [markdown]
# ### Q4.a

# %% [markdown]
#  - GridSearch is not part of this module. If trieed, well and good. If not, marks should not be deducted.

# %%
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
svc = SVC()
clf = GridSearchCV(svc, parameters)
clf.fit(X, y)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10], 'kernel': ('linear', 'rbf')})

# %% [markdown]
# ### Q4.b

# %%
clf.get_params
# Out:
# <bound method BaseEstimator.get_params of GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10], 'kernel': ('linear', 'rbf')})>

# %%
clf.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
pred_grid = clf.predict(X)

# %% [markdown]
# ### Q4.c

# %%
print(classification_report(y,pred_grid))
# Out:
#               precision    recall  f1-score   support
#
#          bus       1.00      0.99      0.99       205
#          car       1.00      1.00      1.00       413
#          van       0.98      0.99      0.99       195
#
#     accuracy                           0.99       813
#    macro avg       0.99      0.99      0.99       813
# weighted avg       0.99      0.99      0.99       813

# %% [markdown]
# ### Q5.a

# %% [markdown]
# 1. Number of features in the dataset are high and need is to reduce number of dimensions.
# 2. Multicollinearity exixst between the existing features in the Dataset.

# %% [markdown]
# ### Q5.b

# %% [markdown]
# #### Advantages:
# 1. Removes Correlated features
# 2. Avoids overfitting
#
# #### Limitations:
# 1. Loss of interpretability
